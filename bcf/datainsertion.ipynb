# %%
import pandas as pd
df=pd.read_excel("C:/Users/hp/Downloads/bcf_05-07-2024_final.xlsx")

# %%
count =df['Product Name'].str.contains('","', na=False)
print(count)
bisma=df[count]
bisma['Product Name']
for val in range(len(df)):
    if '","' in str(df.at[val,'Product Name']):
        df.at[val, 'Product Name'] = df.at[val, 'Product Name'].split('",')[0].replace("\\","")
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7330    False
# 7331    False
# 7332    False
# 7333    False
# 7334    False
# Name: Product Name, Length: 7335, dtype: bool

# %%
df
# Out:
#            date product_category
# 0    2024-02-07          Boating  \
# 1    2024-02-07          Boating
# 2    2024-02-07          Boating
# 3    2024-02-07          Boating
# 4    2024-02-07          Boating
# ...         ...              ...
# 7330 2024-02-07          Fishing
# 7331 2024-02-07          Fishing
# 7332 2024-02-07          Fishing
# 7333 2024-02-07          Fishing
# 7334 2024-02-07          Fishing
#
#                                             product_url
# 0     https://www.bcf.com.au/p/marlin-australia-adul...  \
# 1     https://www.bcf.com.au/p/marlin-australia-juni...
# 2     https://www.bcf.com.au/p/marlin-australia-chil...
# 3     https://www.bcf.com.au/p/marlin-australia-adul...
# 4     https://www.bcf.com.au/p/adult-motion-neo-spor...
# ...                                                 ...
# 7330  https://www.bcf.com.au/p/maria-duck-dive-float...
# 7331  https://www.bcf.com.au/p/halco-roosta-popper-s...
# ...

# %%
df.to_excel("bcf_05-07-2024_cleaned.xlsx",index=False)

# %%
from sqlalchemy import create_engine
import psycopg2
import psycopg2.extras as extras
try:
#     database_url = "postgresql://doadmin:mq2i4pwpvlen6mho@db-postgresql-sfo3-smartbot-1db-do-user-8157534-0.b.db.ondigitalocean.com:25060/alpha"
    database_url = "postgresql://MSTConsumer@mstconsumer-aimleap:vFQXD3eCt58BvFa@mstconsumer-aimleap.postgres.database.azure.com:5432/postgres"
    engine = create_engine(database_url)
    table_name = 'bcf_raw'
    df.to_sql(table_name, con=engine, if_exists='append', index=False)
    print('File successfully  moved')
except Exception as e:
    print('Error in  movement')
    print(f'Error :- {e}')
# Out:
# File successfully  moved
